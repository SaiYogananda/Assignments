# %% [markdown]
# Problem Statement 1:
#
# Blood glucose levels for obese patients have a mean of 100 with a standard deviation of 15. A researcher thinks that a diet high in raw cornstarch will have a positive effect on blood glucose levels. A sample of 36 patients who have tried the raw cornstarch diet have a mean glucose level of 108. Test the hypothesis that the raw cornstarch had an effect or not.

# %% [markdown]
# Given
#
# population mean(mu)=100
#
# population standard deviation(sigma)=15
#
# sample size n=36
#
# sample mean(x_bar)=108
#
#
#
# Null hypothesis(H_0)      : population mean (mu) = 100
#
# Alternate hypothesis(H_a) : population mean (mu) > 100
#
# Lets assume the significance level to be 5% or 0.05
#
# Formula for test statistic value:
#
# ![image.png](attachment:image.png)
#
#
# Z=(108-100)/(15/sqrt(36))
#
# Z=3.2
#
#
# Probability of having a value greater than 108 is given by P(Z>3.2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The P-value associated with the Z-value of 3.2 is 0.9993 . This means that the probability of having a value less than 108 is 0.9993, while the probability of having a value equal to or more than 108 is (1-0.9993), which is equal to 0.0007.
#
# As the computed value of 0.0007 is less than the significance level of 0.05, the Null hypothesis  can be rejected.
# So there is a rawcorn starch effect .

# %% [markdown]
# Problem Statement 2:
#
# In one state, 52% of the voters are Republicans, and 48% are Democrats. In a second state, 47% of the voters are Republicans, and 53% are Democrats. Suppose a simple random sample of 100 voters are surveyed from each state.
#
# What is the probability that the survey will show a greater percentage of Republican voters in the second state than in the first state?

# %% [markdown]
# Let P1 = the proportion of Republican voters in the first state
#
# Let P2 = the proportion of Republican voters in the second state
#
# Let p1 = the proportion of Republican voters in the sample from the first state
#
# Let p2 = the proportion of Republican voters in the sample from the second state
#
# The number of voters sampled from the first state (n1) = 100
#
# The number of voters sampled from the second state (n2) = 100
#
#
# The samples from each population must be big enough to justify using a normal distribution to model differences between proportions.The sample sizes will be big enough when the following conditions are met:
#
# 1)  n1 * P1 >= 10
#
#    We have P1 = 0.52
#
#    So n1 * P1 = 100 * 0.52 = 52
#
# 2) n1 * (1-P1) >= 10
#
#   So n1 * (1-P1) = 100 * 0.48 = 48
#
# 3) n2 * P2 >= 10
#
#   We have P2 = 0.47
#
#   So n2 * P2 = 100 * 0.47 = 47
#
# 4) n2 * (1-P2) >= 10
#
#   So n2 * (1-P2) = 100 * 53 = 53
#
#
#  Since all the conditions have met, the sample size is large enough.
#
#  Since the expected value of the difference between all possible sample proportions is equal to the difference between population proportions.
#
#  So E(p1 - p2) = P1 - P2  = 0.52 - 0.47 = 0.05
#
#  The standard deviation of the difference between sample proportions  is approximately equal to:
#
#  sqrt( ((P1*(1 - P1)) / n1) + ((P2*(1 - P2)) / n2) )  = 0.0706
#
#
#   This problem requires us to find the probability that p2 is greater than p1. This is equivalent to finding the probability that p1 - p2 is less than zero.
#
#
#  So Z_(p1 - p2) = (x - mu_(p1 - p2)) / sigma_(p1-p2)  = (0 - 0.05)/0.0706 = -0.7082
#
# We find that the probability of a z-score less than or equal to -0.7082 is  0.2419
#
#
# Therefore, the probability that the survey will show a greater percentage of Republican voters inthe second state than in the first state is 0.24 approximately.

# %% [markdown]
# Problem Statement 3:
#
# You take the SAT and score 1100. The mean score for the SAT is 1026 and the standard deviation is 209. How well did you score on the test compared to the average test taker?

# %% [markdown]
# Given Random_variable x_i = 1100
#
#  mean (mu) = 1026
#
#  standard deviation (sigma) = 209
#
#  Z_score = (x_i - mu)/sigma  =  (1100-1026)/209 = 0.354
#
#  This means that the score(1100) was 0.354 standard deviations above the mean.
#
#  When we look into the Z-table for the value associated with  0.35 standard deviations we get 0.6368 which means that 63.68 %    of test takers have scored less than 1100.
